# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings 
warnings.filterwarnings("ignore")

# %%
df = sns.load_dataset("mpg")
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# 1            70     usa          buick skylark 320
# 2            70     usa         plymouth satellite
# 3            70     usa              amc rebel sst
# 4            70     usa                ford torino
# ..          ...     ...                        ...
# 393          82     usa            ford mustang gl
# 394          82  europe                  vw pickup
# 395          82     usa              dodge rampage
# 396          82     usa                ford ranger
# 397          82     usa                 chevy s-10
#
# [398 rows x 9 columns]

# %%
df.drop("name",axis=1,inplace=True)

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin
# 0          70    usa
# 1          70    usa
# 2          70    usa
# 3          70    usa
# 4          70    usa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 25.0+ KB

# %%
df.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64

# %%
#  since we have not done outlier treatment yet, we will fill the missing values with median
df["horsepower"].fillna(df["horsepower"].median(),inplace=True)

# %%
df.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64

# %%
df['origin'].value_counts()
# Out:
# origin
# usa       249
# japan      79
# europe     70
# Name: count, dtype: int64

# %%
# data encoding
df["origin"] = df["origin"].map({"usa": 1, "japan": 2, "europe": 3})

# %%
df["origin"].value_counts()
# Out:
# origin
# 1    249
# 2     79
# 3     70
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model_year        int64
# origin            int64
# dtype: object

# %%
# separate into x and y 
x = df.drop("mpg",axis=1)
y = df["mpg"]

# %%
x
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 0            8         307.0       130.0    3504          12.0          70
# 1            8         350.0       165.0    3693          11.5          70
# 2            8         318.0       150.0    3436          11.0          70
# 3            8         304.0       150.0    3433          12.0          70
# 4            8         302.0       140.0    3449          10.5          70
# ..         ...           ...         ...     ...           ...         ...
# 393          4         140.0        86.0    2790          15.6          82
# 394          4          97.0        52.0    2130          24.6          82
# 395          4         135.0        84.0    2295          11.6          82
# 396          4         120.0        79.0    2625          18.6          82
# 397          4         119.0        82.0    2720          19.4          82
#
#      origin
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ..      ...
# 393       1
# 394       3
# 395       1
# 396       1
# 397       1
#
# [398 rows x 7 columns]

# %%
y
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %%
# train test split

from sklearn.model_selection import train_test_split
x_train, x_test, y_train,y_test = train_test_split(x,y, test_size = 0.3 , random_state = 1)

# %%
# scaling
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# scaler

# %%
# x_train = scaler.fit_transform(x_train)
# x_test = scaler.transform(x_test)

# %%
x_train
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 350          4         105.0        63.0    2215          14.9          81
# 59           4          97.0        54.0    2254          23.5          72
# 120          4         121.0       112.0    2868          15.5          73
# 12           8         400.0       150.0    3761           9.5          70
# 349          4          91.0        68.0    1985          16.0          81
# ..         ...           ...         ...     ...           ...         ...
# 393          4         140.0        86.0    2790          15.6          82
# 255          4         140.0        88.0    2720          15.4          78
# 72           8         304.0       150.0    3892          12.5          72
# 235          4          97.0        75.0    2265          18.2          77
# 37           6         232.0       100.0    3288          15.5          71
#
#      origin
# 350       1
# 59        3
# 120       3
# 12        1
# 349       2
# ..      ...
# 393       1
# 255       1
# 72        1
# 235       2
# 37        1
#
# [278 rows x 7 columns]

# %%
x_test
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 174          6         171.0        97.0    2984          14.5          75
# 359          4         141.0        80.0    3230          20.4          81
# 250          8         318.0       140.0    3735          13.2          78
# 274          5         131.0       103.0    2830          15.9          78
# 283          6         232.0        90.0    3265          18.2          79
# ..         ...           ...         ...     ...           ...         ...
# 382          4         108.0        70.0    2245          16.9          82
# 39           8         400.0       175.0    4464          11.5          71
# 171          4         134.0        96.0    2702          13.5          75
# 271          4         156.0       105.0    2745          16.7          78
# 247          4          85.0        70.0    2070          18.6          78
#
#      origin
# 174       1
# 359       3
# 250       1
# 274       3
# 283       1
# ..      ...
# 382       2
# 39        1
# 171       2
# 271       1
# 247       2
#
# [120 rows x 7 columns]

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([-0.31761423,  0.02623748, -0.01827076, -0.00748775,  0.05040673,
#         0.84709514,  1.51909584])

# %%
for i ,col_name in enumerate(x_train.columns):
    print(f"the coefficient for {col_name} is {model.coef_[i]}")
# Out:
# the coefficient for cylinders is -0.3176142302799369
# the coefficient for displacement is 0.026237482599078946
# the coefficient for horsepower is -0.018270764913124595
# the coefficient for weight is -0.007487750398361897
# the coefficient for acceleration is 0.0504067346197138
# the coefficient for model_year is 0.8470951427061365
# the coefficient for origin is 1.5190958387975024

# %%
print(model.coef_.shape)
# Out:
# (7,)

# %%
# observations :
# coefficients are relatively smaller , if one independent variable changes
# there will be not much difference in prediction
# this is sometime called as smoother model

# these  features might not be contributing in model training

# %%
model.intercept_
# Out:
# np.float64(-23.085380742316662)

# %%
from sklearn.metrics import mean_squared_error, r2_score
y_pred = model.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %%
print("Predictions:", y_pred)
# Out:
# Predictions: [21.16196121 27.89684387 20.45045592 27.12361164 24.36117063 15.87763934
#  29.93157794 34.02155729 17.08992155 10.56782304 30.53231377 16.48854992
#  22.4061424  27.76978226 36.0209892  23.79725872 10.82747269 20.27707855
#   8.86935273 32.48801009 25.36507567 32.75235387 20.95486868 24.54530695
#  25.77582154 30.20140405 32.01102103 31.96692512 15.25929349 30.41225966
#  27.50427715 10.93370544 21.42816438 28.08300976 25.03368839 13.67199264
#  26.67769394  9.04050101 32.03270673 23.97429191 24.18855895 24.60440771
#  21.16368861 34.53665774 26.31981331 22.23170907 21.0865992  11.65432984
#  27.9398198  18.98058597 23.69821181 26.86564242 17.04794305 12.03955477
#  28.70876897 24.26227131 10.20293895 13.03594704 29.96910853 35.35029687
#  37.01162788 35.38558158 18.04991116 27.90304164 20.67174751 33.83899858
#  27.02537633 26.73184442 29.93216787 12.33895062 20.55262443 22.65714109
#  14.56684563 26.56065611 11.62492303 25.65879286 28.51627153 16.50467141
#  11.74025745 24.51069859 21.38744145 20.41346334 35.04406263 23.94777428
#  34.05299044 18.39944347 15.25881993 23.87549502 36.12773335 33.15643364
#  19.79370149 22.55763359 20.85182014 26.88839011 31.8751037  22.49875976
#  32.61695661 28.98417667 23.01603316 24.38485151 21.17267146  7.56528875
#  15.68250233 33.90060931 12.5842524  22.36320802 31.13046288 23.99262475
#  27.92346553 17.59905938 19.46074471 30.42223204 29.28685517 16.84446904
#  24.74015144 33.74072446 10.48852524 24.42490829 25.6992139  31.14492956]

# %%
print("Mean Squared Error:", mse)
print("R^2 Score:", r2)
# Out:
# Mean Squared Error: 9.658732193155872
# R^2 Score: 0.8348001123742285

# %%
# regularised model 
# ridge regression

from sklearn.linear_model import Ridge

# in practical implementation lambda is alpha 

ridge_model = Ridge(alpha=1.0)
ridge_model
# Out:
# Ridge()

# %%
ridge_model.fit(x_train,y_train)
# Out:
# Ridge()

# %%
for i ,col_name in enumerate(x_train.columns):
    print(f"the coefficient for {col_name} is {ridge_model.coef_[i]}")
# Out:
# the coefficient for cylinders is -0.31159794459952483
# the coefficient for displacement is 0.02599797725360628
# the coefficient for horsepower is -0.01819643128246157
# the coefficient for weight is -0.0074835421258030175
# the coefficient for acceleration is 0.05003261423029815
# the coefficient for model_year is 0.8462126659579847
# the coefficient for origin is 1.5028233365628925

# %%
# for ridge regression evaluation 
y_ridge_pred = ridge_model.predict(x_test)
r2_ridge = r2_score(y_test, y_ridge_pred)
print(f"The R^2 score for ridge regression is {r2_ridge}")
# Out:
# The R^2 score for ridge regression is 0.8348814925912453

# %%
# we dont see much variation in coeff of ridge regression as compared to linear regression

# %%
from sklearn.linear_model import Lasso

# %%
lasso_model = Lasso(alpha=0.5)
lasso_model
# Out:
# Lasso(alpha=0.5)

# %%
lasso_model.fit(x_train, y_train)
# Out:
# Lasso(alpha=0.5)

# %%
lasso_model.coef_
# Out:
# array([-0.        ,  0.0062082 , -0.01105838, -0.00698267,  0.        ,
#         0.74465495,  0.        ])

# %%
lasso_model.fit(x_train, y_train)
for i ,col_name in enumerate(x_train.columns):
    print(f"the coefficient for {col_name} is {lasso_model.coef_[i]}")
# Out:
# the coefficient for cylinders is -0.0
# the coefficient for displacement is 0.006208198888300358
# the coefficient for horsepower is -0.011058382987169565
# the coefficient for weight is -0.0069826731680230885
# the coefficient for acceleration is 0.0
# the coefficient for model_year is 0.744654952003819
# the coefficient for origin is 0.0

# %%
#three features coefficient is 0, lasso helps in feature selection

# %%
y_lasso_pred = lasso_model.predict(x_test)
r2_lasso = r2_score(y_test, y_lasso_pred)
print(f"The R^2 score for lasso regression is {r2_lasso}")
# Out:
# The R^2 score for lasso regression is 0.8277934716635555

# %%
# elastic net regression
from sklearn.linear_model import ElasticNet
elastic_model = ElasticNet(alpha=1, l1_ratio=0.5)
elastic_model.fit(x_train, y_train)
# Out:
# ElasticNet(alpha=1)

# %%
elastic_model.fit(x_train, y_train)
for i ,col_name in enumerate(x_train.columns):
    print(f"the coefficient for {col_name} is {elastic_model.coef_[i]}")
# Out:
# the coefficient for cylinders is -0.0
# the coefficient for displacement is 0.005888869953667563
# the coefficient for horsepower is -0.012403874933570126
# the coefficient for weight is -0.006934550516257631
# the coefficient for acceleration is 0.0
# the coefficient for model_year is 0.7133150744603874
# the coefficient for origin is 0.0

# %%
y_pred_elastic = elastic_model.predict(x_test)
r2_elastic = r2_score(y_test, y_pred_elastic)
print(f"The R^2 score for elastic net regression is {r2_elastic}")
# Out:
# The R^2 score for elastic net regression is 0.8284840073256804

# %%
#regularisation with crossvalidation 
from sklearn.linear_model import LassoCV
lasso_cv = LassoCV(cv = 5, verbose=2)

# %%
lasso_cv
# Out:
# LassoCV(cv=5, verbose=2)

# %%
lasso_cv.fit(x_train, y_train)
# Out:
# Path: 000 out of 100
# Path: 001 out of 100
# Path: 002 out of 100
# Path: 003 out of 100
# Path: 004 out of 100
# Path: 005 out of 100
# Path: 006 out of 100
# Path: 007 out of 100
# Path: 008 out of 100
# Path: 009 out of 100
# Path: 010 out of 100
# Path: 011 out of 100
# Path: 012 out of 100
# Path: 013 out of 100
# Path: 014 out of 100
# Path: 015 out of 100
# Path: 016 out of 100
# Path: 017 out of 100
# Path: 018 out of 100
# Path: 019 out of 100
# Path: 020 out of 100
# Path: 021 out of 100
# Path: 022 out of 100
# Path: 023 out of 100
# Path: 024 out of 100
# Path: 025 out of 100
# Path: 026 out of 100
# Path: 027 out of 100
# Path: 028 out of 100
# Path: 029 out of 100
# Path: 030 out of 100
# Path: 031 out of 100
# Path: 032 out of 100
# Path: 033 out of 100
# Path: 034 out of 100
# Path: 035 out of 100
# Path: 036 out of 100
# Path: 037 out of 100
# Path: 038 out of 100
# Path: 039 out of 100
# Path: 040 out of 100
# Path: 041 out of 100
# Path: 042 out of 100
# Path: 043 out of 100
# Path: 044 out of 100
# Path: 045 out of 100
# Path: 046 out of 100
# Path: 047 out of 100
# Path: 048 out of 100
# Path: 049 out of 100
# Path: 050 out of 100
# Path: 051 out of 100
# Path: 052 out of 100
# Path: 053 out of 100
# Path: 054 out of 100
# Path: 055 out of 100
# Path: 056 out of 100
# Path: 057 out of 100
# Path: 058 out of 100
# Path: 059 out of 100
# Path: 060 out of 100
# Path: 061 out of 100
# Path: 062 out of 100
# Path: 063 out of 100
# Path: 064 out of 100
# Path: 065 out of 100
# Path: 066 out of 100
# Path: 067 out of 100
# Path: 068 out of 100
# Path: 069 out of 100
# Path: 070 out of 100
# Path: 071 out of 100
# Path: 072 out of 100
# Path: 073 out of 100
# Path: 074 out of 100
# Path: 075 out of 100
# Path: 076 out of 100
# Path: 077 out of 100
# Path: 078 out of 100
# Path: 079 out of 100
# Path: 080 out of 100
# Path: 081 out of 100
# Path: 082 out of 100
# Path: 083 out of 100
# Path: 084 out of 100
# Path: 085 out of 100
# Path: 086 out of 100
# Path: 087 out of 100
# Path: 088 out of 100
# Path: 089 out of 100
# Path: 090 out of 100
# Path: 091 out of 100
# Path: 092 out of 100
# Path: 093 out of 100
# Path: 094 out of 100
# Path: 095 out of 100
# Path: 096 out of 100
# Path: 097 out of 100
# Path: 098 out of 100
# Path: 099 out of 100
# Path: 000 out of 100
# Path: 001 out of 100
# Path: 002 out of 100
# Path: 003 out of 100
# Path: 004 out of 100
# Path: 005 out of 100
# Path: 006 out of 100
# Path: 007 out of 100
# Path: 008 out of 100
# Path: 009 out of 100
# Path: 010 out of 100
# Path: 011 out of 100
# Path: 012 out of 100
# Path: 013 out of 100
# Path: 014 out of 100
# Path: 015 out of 100
# Path: 016 out of 100
# Path: 017 out of 100
# Path: 018 out of 100
# Path: 019 out of 100
# Path: 020 out of 100
# Path: 021 out of 100
# Path: 022 out of 100
# Path: 023 out of 100
# Path: 024 out of 100
# Path: 025 out of 100
# Path: 026 out of 100
# Path: 027 out of 100
# Path: 028 out of 100
# Path: 029 out of 100
# Path: 030 out of 100
# Path: 031 out of 100
# Path: 032 out of 100
# Path: 033 out of 100
# Path: 034 out of 100
# Path: 035 out of 100
# Path: 036 out of 100
# Path: 037 out of 100
# Path: 038 out of 100
# Path: 039 out of 100
# Path: 040 out of 100
# Path: 041 out of 100
# Path: 042 out of 100
# Path: 043 out of 100
# Path: 044 out of 100
# Path: 045 out of 100
# Path: 046 out of 100
# Path: 047 out of 100
# Path: 048 out of 100
# Path: 049 out of 100
# Path: 050 out of 100
# Path: 051 out of 100
# Path: 052 out of 100
# Path: 053 out of 100
# Path: 054 out of 100
# Path: 055 out of 100
# Path: 056 out of 100
# Path: 057 out of 100
# Path: 058 out of 100
# Path: 059 out of 100
# Path: 060 out of 100
# Path: 061 out of 100
# Path: 062 out of 100
# Path: 063 out of 100
# Path: 064 out of 100
# Path: 065 out of 100
# Path: 066 out of 100
# Path: 067 out of 100
# Path: 068 out of 100
# Path: 069 out of 100
# Path: 070 out of 100
# Path: 071 out of 100
# Path: 072 out of 100
# Path: 073 out of 100
# Path: 074 out of 100
# Path: 075 out of 100
# Path: 076 out of 100
# Path: 077 out of 100
# Path: 078 out of 100
# Path: 079 out of 100
# Path: 080 out of 100
# Path: 081 out of 100
# Path: 082 out of 100
# Path: 083 out of 100
# Path: 084 out of 100
# Path: 085 out of 100
# Path: 086 out of 100
# Path: 087 out of 100
# Path: 088 out of 100
# Path: 089 out of 100
# Path: 090 out of 100
# Path: 091 out of 100
# Path: 092 out of 100
# Path: 093 out of 100
# Path: 094 out of 100
# Path: 095 out of 100
# Path: 096 out of 100
# Path: 097 out of 100
# Path: 098 out of 100
# Path: 099 out of 100
# Path: 000 out of 100
# Path: 001 out of 100
# Path: 002 out of 100
# Path: 003 out of 100
# Path: 004 out of 100
# Path: 005 out of 100
# Path: 006 out of 100
# Path: 007 out of 100
# Path: 008 out of 100
# Path: 009 out of 100
# Path: 010 out of 100
# Path: 011 out of 100
# Path: 012 out of 100
# Path: 013 out of 100
# Path: 014 out of 100
# Path: 015 out of 100
# Path: 016 out of 100
# Path: 017 out of 100
# Path: 018 out of 100
# Path: 019 out of 100
# Path: 020 out of 100
# Path: 021 out of 100
# Path: 022 out of 100
# Path: 023 out of 100
# Path: 024 out of 100
# Path: 025 out of 100
# Path: 026 out of 100
# Path: 027 out of 100
# Path: 028 out of 100
# Path: 029 out of 100
# Path: 030 out of 100
# Path: 031 out of 100
# Path: 032 out of 100
# Path: 033 out of 100
# Path: 034 out of 100
# Path: 035 out of 100
# Path: 036 out of 100
# Path: 037 out of 100
# Path: 038 out of 100
# Path: 039 out of 100
# Path: 040 out of 100
# Path: 041 out of 100
# Path: 042 out of 100
# Path: 043 out of 100
# Path: 044 out of 100
# Path: 045 out of 100
# Path: 046 out of 100
# Path: 047 out of 100
# Path: 048 out of 100
# Path: 049 out of 100
# Path: 050 out of 100
# Path: 051 out of 100
# Path: 052 out of 100
# Path: 053 out of 100
# Path: 054 out of 100
# Path: 055 out of 100
# Path: 056 out of 100
# Path: 057 out of 100
# Path: 058 out of 100
# Path: 059 out of 100
# Path: 060 out of 100
# Path: 061 out of 100
# Path: 062 out of 100
# Path: 063 out of 100
# Path: 064 out of 100
# Path: 065 out of 100
# Path: 066 out of 100
# Path: 067 out of 100
# Path: 068 out of 100
# Path: 069 out of 100
# Path: 070 out of 100
# Path: 071 out of 100
# Path: 072 out of 100
# Path: 073 out of 100
# Path: 074 out of 100
# Path: 075 out of 100
# Path: 076 out of 100
# Path: 077 out of 100
# Path: 078 out of 100
# Path: 079 out of 100
# Path: 080 out of 100
# Path: 081 out of 100
# Path: 082 out of 100
# Path: 083 out of 100
# Path: 084 out of 100
# Path: 085 out of 100
# Path: 086 out of 100
# Path: 087 out of 100
# Path: 088 out of 100
# Path: 089 out of 100
# Path: 090 out of 100
# Path: 091 out of 100
# Path: 092 out of 100
# Path: 093 out of 100
# Path: 094 out of 100
# Path: 095 out of 100
# Path: 096 out of 100
# Path: 097 out of 100
# Path: 098 out of 100
# Path: 099 out of 100
# Path: 000 out of 100
# Path: 001 out of 100
# Path: 002 out of 100
# Path: 003 out of 100
# Path: 004 out of 100
# Path: 005 out of 100
# Path: 006 out of 100
# Path: 007 out of 100
# Path: 008 out of 100
# Path: 009 out of 100
# Path: 010 out of 100
# Path: 011 out of 100
# Path: 012 out of 100
# Path: 013 out of 100
# Path: 014 out of 100
# Path: 015 out of 100
# Path: 016 out of 100
# Path: 017 out of 100
# Path: 018 out of 100
# Path: 019 out of 100
# Path: 020 out of 100
# Path: 021 out of 100
# Path: 022 out of 100
# Path: 023 out of 100
# Path: 024 out of 100
# Path: 025 out of 100
# Path: 026 out of 100
# Path: 027 out of 100
# Path: 028 out of 100
# Path: 029 out of 100
# Path: 030 out of 100
# Path: 031 out of 100
# Path: 032 out of 100
# Path: 033 out of 100
# Path: 034 out of 100
# Path: 035 out of 100
# Path: 036 out of 100
# Path: 037 out of 100
# Path: 038 out of 100
# Path: 039 out of 100
# Path: 040 out of 100
# Path: 041 out of 100
# Path: 042 out of 100
# Path: 043 out of 100
# Path: 044 out of 100
# Path: 045 out of 100
# Path: 046 out of 100
# Path: 047 out of 100
# Path: 048 out of 100
# Path: 049 out of 100
# Path: 050 out of 100
# Path: 051 out of 100
# Path: 052 out of 100
# Path: 053 out of 100
# Path: 054 out of 100
# Path: 055 out of 100
# Path: 056 out of 100
# Path: 057 out of 100
# Path: 058 out of 100
# Path: 059 out of 100
# Path: 060 out of 100
# Path: 061 out of 100
# Path: 062 out of 100
# Path: 063 out of 100
# Path: 064 out of 100
# Path: 065 out of 100
# Path: 066 out of 100
# Path: 067 out of 100
# Path: 068 out of 100
# Path: 069 out of 100
# Path: 070 out of 100
# Path: 071 out of 100
# Path: 072 out of 100
# Path: 073 out of 100
# Path: 074 out of 100
# Path: 075 out of 100
# Path: 076 out of 100
# Path: 077 out of 100
# Path: 078 out of 100
# Path: 079 out of 100
# Path: 080 out of 100
# Path: 081 out of 100
# Path: 082 out of 100
# Path: 083 out of 100
# Path: 084 out of 100
# Path: 085 out of 100
# Path: 086 out of 100
# Path: 087 out of 100
# Path: 088 out of 100
# Path: 089 out of 100
# Path: 090 out of 100
# Path: 091 out of 100
# Path: 092 out of 100
# Path: 093 out of 100
# Path: 094 out of 100
# Path: 095 out of 100
# Path: 096 out of 100
# Path: 097 out of 100
# Path: 098 out of 100
# Path: 099 out of 100
# Path: 000 out of 100
# Path: 001 out of 100
# Path: 002 out of 100
# Path: 003 out of 100
# Path: 004 out of 100
# Path: 005 out of 100
# Path: 006 out of 100
# Path: 007 out of 100
# Path: 008 out of 100
# Path: 009 out of 100
# Path: 010 out of 100
# Path: 011 out of 100
# Path: 012 out of 100
# Path: 013 out of 100
# Path: 014 out of 100
# Path: 015 out of 100
# Path: 016 out of 100
# Path: 017 out of 100
# Path: 018 out of 100
# Path: 019 out of 100
# Path: 020 out of 100
# Path: 021 out of 100
# Path: 022 out of 100
# Path: 023 out of 100
# Path: 024 out of 100
# Path: 025 out of 100
# Path: 026 out of 100
# Path: 027 out of 100
# Path: 028 out of 100
# Path: 029 out of 100
# Path: 030 out of 100
# Path: 031 out of 100
# Path: 032 out of 100
# Path: 033 out of 100
# Path: 034 out of 100
# Path: 035 out of 100
# Path: 036 out of 100
# Path: 037 out of 100
# Path: 038 out of 100
# Path: 039 out of 100
# Path: 040 out of 100
# Path: 041 out of 100
# Path: 042 out of 100
# Path: 043 out of 100
# Path: 044 out of 100
# Path: 045 out of 100
# Path: 046 out of 100
# Path: 047 out of 100
# Path: 048 out of 100
# Path: 049 out of 100
# Path: 050 out of 100
# Path: 051 out of 100
# Path: 052 out of 100
# Path: 053 out of 100
# Path: 054 out of 100
# Path: 055 out of 100
# Path: 056 out of 100
# Path: 057 out of 100
# Path: 058 out of 100
# Path: 059 out of 100
# Path: 060 out of 100
# Path: 061 out of 100
# Path: 062 out of 100
# Path: 063 out of 100
# Path: 064 out of 100
# Path: 065 out of 100
# Path: 066 out of 100
# Path: 067 out of 100
# Path: 068 out of 100
# Path: 069 out of 100
# Path: 070 out of 100
# Path: 071 out of 100
# Path: 072 out of 100
# Path: 073 out of 100
# Path: 074 out of 100
# Path: 075 out of 100
# Path: 076 out of 100
# Path: 077 out of 100
# Path: 078 out of 100
# Path: 079 out of 100
# Path: 080 out of 100
# Path: 081 out of 100
# Path: 082 out of 100
# Path: 083 out of 100
# Path: 084 out of 100
# Path: 085 out of 100
# Path: 086 out of 100
# Path: 087 out of 100
# Path: 088 out of 100
# Path: 089 out of 100
# Path: 090 out of 100
# Path: 091 out of 100
# Path: 092 out of 100
# Path: 093 out of 100
# Path: 094 out of 100
# Path: 095 out of 100
# Path: 096 out of 100
# Path: 097 out of 100
# Path: 098 out of 100
# Path: 099 out of 100
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.0s finished
# LassoCV(cv=5, verbose=2)

# %%
y_pred = lasso_cv.predict(x_test)
score = r2_score(y_test, y_pred)
print(f"The R square of Lasso CV {score}")
# Out:
# The R square of Lasso CV 0.8082805983844751

# %%
from sklearn.linear_model import RidgeCV
ridgecv = RidgeCV(cv = 5)
ridgecv.fit(x_train, y_train)
# Out:
# RidgeCV(cv=5)

# %%
y_pred = ridgecv.predict(x_test)
r2_score(y_test, y_pred)
# Out:
# 0.8354145247502055

# %%
ridgecv.get_params()
# Out:
# {'alpha_per_target': False,
#  'alphas': (0.1, 1.0, 10.0),
#  'cv': 5,
#  'fit_intercept': True,
#  'gcv_mode': None,
#  'scoring': None,
#  'store_cv_results': False}

# %%
from sklearn.linear_model import ElasticNetCV

# %%
elastic_cv = ElasticNetCV(cv = 5)
elastic_cv.fit(x_train, y_train)
# Out:
# ElasticNetCV(cv=5)

# %%
y_pred = elastic_cv.predict(x_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.792863401804916

# %% [markdown]
# #CV with hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.linear_model import Lasso, Ridge

# %%
# grid searchcv for lasso 
# define the model
lasso = Lasso()

# %%
lasso
# Out:
# Lasso()

# %%
#grid search cv>> Dictionary with parameters names (str) as keys and lists of parameter settings to try as value

param_grid = {'alpha': [0.001, 0.01, 0.1, 1, 10, 100]}
param_grid
# Out:
# {'alpha': [0.001, 0.01, 0.1, 1, 10, 100]}

# %%
grid_search = GridSearchCV(estimator = lasso, param_grid=param_grid, cv=5, scoring='r2', verbose = 2)

# %%
grid_search
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.001, 0.01, 0.1, 1, 10, 100]}, scoring='r2',
#              verbose=2)

# %%
grid_search.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ............................................alpha=1; total time=   0.0s
# [CV] END ............................................alpha=1; total time=   0.0s
# [CV] END ............................................alpha=1; total time=   0.0s
# [CV] END ............................................alpha=1; total time=   0.0s
# [CV] END ............................................alpha=1; total time=   0.0s
# [CV] END ...........................................alpha=10; total time=   0.0s
# [CV] END ...........................................alpha=10; total time=   0.0s
# [CV] END ...........................................alpha=10; total time=   0.0s
# [CV] END ...........................................alpha=10; total time=   0.0s
# [CV] END ...........................................alpha=10; total time=   0.0s
# [CV] END ..........................................alpha=100; total time=   0.0s
# [CV] END ..........................................alpha=100; total time=   0.0s
# [CV] END ..........................................alpha=100; total time=   0.0s
# [CV] END ..........................................alpha=100; total time=   0.0s
# [CV] END ..........................................alpha=100; total time=   0.0s
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.001, 0.01, 0.1, 1, 10, 100]}, scoring='r2',
#              verbose=2)

# %%
grid_search.best_params_
# Out:
# {'alpha': 0.1}

# %%
grid_search.best_params_["alpha"]
# Out:
# 0.1

# %%
grid_search.best_score_ #Mean(avg) cross-validated score of the best_estimator
# Out:
# np.float64(0.7964209726696481)

# %%
grid_search.best_estimator_
#Estimator that was chosen by the search, i.e. estimator which gave highest score (or smallest loss if specified) on the left out data
# Out:
# Lasso(alpha=0.1)

# %%
y_pred = grid_search.best_estimator_.predict(x_test)
r2_score(y_test, y_pred)
# Out:
# 0.8345318641232303

# %% [markdown]
# # Randomized search cv

# %%
# Randomized search cv for lasso

lasso = Lasso()
param_distributions = {"alpha": [0.001 , 0.01, 0.1,1,10,100]}
random_search_lasso = RandomizedSearchCV(estimator=lasso, param_distributions=param_distributions, n_iter = 3, cv=5, scoring='r2', verbose=2)
random_search_lasso
# Out:
# RandomizedSearchCV(cv=5, estimator=Lasso(), n_iter=3,
#                    param_distributions={'alpha': [0.001, 0.01, 0.1, 1, 10,
#                                                   100]},
#                    scoring='r2', verbose=2)

# %%
random_search_lasso.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END ............................................alpha=1; total time=   0.0s
# [CV] END ............................................alpha=1; total time=   0.0s
# [CV] END ............................................alpha=1; total time=   0.0s
# [CV] END ............................................alpha=1; total time=   0.0s
# [CV] END ............................................alpha=1; total time=   0.0s
# RandomizedSearchCV(cv=5, estimator=Lasso(), n_iter=3,
#                    param_distributions={'alpha': [0.001, 0.01, 0.1, 1, 10,
#                                                   100]},
#                    scoring='r2', verbose=2)

# %%
random_search_lasso.best_params_
# Out:
# {'alpha': 0.01}

# %%
random_search_lasso.best_score_
# Out:
# np.float64(0.7944410612391779)

# %%
random_search_lasso.best_estimator_
# Out:
# Lasso(alpha=0.01)

# %%
y_pred = random_search_lasso.best_estimator_.predict(x_test)
r2_score(y_test, y_pred)
# Out:
# 0.8348812953883181

# %%
# ridge search cv 
ridge = Ridge()
param_grid = {'alpha': [0.001, 0.01, 0.1, 1, 10, 100]}
param_grid
# Out:
# {'alpha': [0.001, 0.01, 0.1, 1, 10, 100]}

# %%
ridge = GridSearchCV(estimator = ridge, param_grid=param_grid, cv=5, scoring='r2', verbose = 2)

# %%
ridge.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ............................................alpha=1; total time=   0.0s
# [CV] END ............................................alpha=1; total time=   0.0s
# [CV] END ............................................alpha=1; total time=   0.0s
# [CV] END ............................................alpha=1; total time=   0.0s
# [CV] END ............................................alpha=1; total time=   0.0s
# [CV] END ...........................................alpha=10; total time=   0.0s
# [CV] END ...........................................alpha=10; total time=   0.0s
# [CV] END ...........................................alpha=10; total time=   0.0s
# [CV] END ...........................................alpha=10; total time=   0.0s
# [CV] END ...........................................alpha=10; total time=   0.0s
# [CV] END ..........................................alpha=100; total time=   0.0s
# [CV] END ..........................................alpha=100; total time=   0.0s
# [CV] END ..........................................alpha=100; total time=   0.0s
# [CV] END ..........................................alpha=100; total time=   0.0s
# [CV] END ..........................................alpha=100; total time=   0.0s
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.001, 0.01, 0.1, 1, 10, 100]}, scoring='r2',
#              verbose=2)

# %%
ridge.best_params_
# Out:
# {'alpha': 10}

# %%
ridge.best_score_
# Out:
# np.float64(0.7943589846334784)

# %%
ridge.best_estimator_
# Out:
# Ridge(alpha=10)

# %%
y_pred= ridge.best_estimator_.predict(x_test)
r2_score(y_test, y_pred)
# Out:
# 0.8354145247502055

# %%
# ridge randomised search cv
ridge = Ridge()
param_distributions = {"alpha": [0.001 , 0.01, 0.1,1,10,100]}
ridge = RandomizedSearchCV(estimator = ridge, param_distributions=param_distributions, n_iter=3, cv=5, scoring='r2', verbose = 2)

ridge.fit(x_train, y_train)
print(ridge.best_params_)
print(ridge.best_estimator_)
print(ridge.best_score_)
y_pred= ridge.best_estimator_.predict(x_test)
r2_score(y_test, y_pred)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=100; total time=   0.0s
# [CV] END ..........................................alpha=100; total time=   0.0s
# [CV] END ..........................................alpha=100; total time=   0.0s
# [CV] END ..........................................alpha=100; total time=   0.0s
# [CV] END ..........................................alpha=100; total time=   0.0s
# [CV] END ...........................................alpha=10; total time=   0.0s
# [CV] END ...........................................alpha=10; total time=   0.0s
# [CV] END ...........................................alpha=10; total time=   0.0s
# [CV] END ...........................................alpha=10; total time=   0.0s
# [CV] END ...........................................alpha=10; total time=   0.0s
# {'alpha': 10}
# Ridge(alpha=10)
# 0.7943589846334784
# 0.8354145247502055

# %%
# Elastic net Grid search cv
model = ElasticNet()
param_grid = {'alpha': [0.001, 0.01, 0.1, 1, 10, 100], 'l1_ratio':[0.1,0.4,0.9]}
model = GridSearchCV(estimator = model, param_grid=param_grid, cv=5, scoring='r2', verbose = 2)

model.fit(x_train, y_train)
print(model.best_params_)
print(model.best_estimator_)
print(model.best_score_)
y_pred= model.best_estimator_.predict(x_test)
r2_score(y_test, y_pred)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV] END ..........................alpha=0.001, l1_ratio=0.1; total time=   0.0s
# [CV] END ..........................alpha=0.001, l1_ratio=0.1; total time=   0.0s
# [CV] END ..........................alpha=0.001, l1_ratio=0.1; total time=   0.0s
# [CV] END ..........................alpha=0.001, l1_ratio=0.1; total time=   0.0s
# [CV] END ..........................alpha=0.001, l1_ratio=0.1; total time=   0.0s
# [CV] END ..........................alpha=0.001, l1_ratio=0.4; total time=   0.0s
# [CV] END ..........................alpha=0.001, l1_ratio=0.4; total time=   0.0s
# [CV] END ..........................alpha=0.001, l1_ratio=0.4; total time=   0.0s
# [CV] END ..........................alpha=0.001, l1_ratio=0.4; total time=   0.0s
# [CV] END ..........................alpha=0.001, l1_ratio=0.4; total time=   0.0s
# [CV] END ..........................alpha=0.001, l1_ratio=0.9; total time=   0.0s
# [CV] END ..........................alpha=0.001, l1_ratio=0.9; total time=   0.0s
# [CV] END ..........................alpha=0.001, l1_ratio=0.9; total time=   0.0s
# [CV] END ..........................alpha=0.001, l1_ratio=0.9; total time=   0.0s
# [CV] END ..........................alpha=0.001, l1_ratio=0.9; total time=   0.0s
# [CV] END ...........................alpha=0.01, l1_ratio=0.1; total time=   0.0s
# [CV] END ...........................alpha=0.01, l1_ratio=0.1; total time=   0.0s
# [CV] END ...........................alpha=0.01, l1_ratio=0.1; total time=   0.0s
# [CV] END ...........................alpha=0.01, l1_ratio=0.1; total time=   0.0s
# [CV] END ...........................alpha=0.01, l1_ratio=0.1; total time=   0.0s
# [CV] END ...........................alpha=0.01, l1_ratio=0.4; total time=   0.0s
# [CV] END ...........................alpha=0.01, l1_ratio=0.4; total time=   0.0s
# [CV] END ...........................alpha=0.01, l1_ratio=0.4; total time=   0.0s
# [CV] END ...........................alpha=0.01, l1_ratio=0.4; total time=   0.0s
# [CV] END ...........................alpha=0.01, l1_ratio=0.4; total time=   0.0s
# [CV] END ...........................alpha=0.01, l1_ratio=0.9; total time=   0.0s
# [CV] END ...........................alpha=0.01, l1_ratio=0.9; total time=   0.0s
# [CV] END ...........................alpha=0.01, l1_ratio=0.9; total time=   0.0s
# [CV] END ...........................alpha=0.01, l1_ratio=0.9; total time=   0.0s
# [CV] END ...........................alpha=0.01, l1_ratio=0.9; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.4; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.4; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.4; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.4; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.4; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.9; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.9; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.9; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.9; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.9; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.1; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.1; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.1; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.1; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.1; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.4; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.4; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.4; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.4; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.4; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.9; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.9; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.9; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.9; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.9; total time=   0.0s
# [CV] END .............................alpha=10, l1_ratio=0.1; total time=   0.0s
# [CV] END .............................alpha=10, l1_ratio=0.1; total time=   0.0s
# [CV] END .............................alpha=10, l1_ratio=0.1; total time=   0.0s
# [CV] END .............................alpha=10, l1_ratio=0.1; total time=   0.0s
# [CV] END .............................alpha=10, l1_ratio=0.1; total time=   0.0s
# [CV] END .............................alpha=10, l1_ratio=0.4; total time=   0.0s
# [CV] END .............................alpha=10, l1_ratio=0.4; total time=   0.0s
# [CV] END .............................alpha=10, l1_ratio=0.4; total time=   0.0s
# [CV] END .............................alpha=10, l1_ratio=0.4; total time=   0.0s
# [CV] END .............................alpha=10, l1_ratio=0.4; total time=   0.0s
# [CV] END .............................alpha=10, l1_ratio=0.9; total time=   0.0s
# [CV] END .............................alpha=10, l1_ratio=0.9; total time=   0.0s
# [CV] END .............................alpha=10, l1_ratio=0.9; total time=   0.0s
# [CV] END .............................alpha=10, l1_ratio=0.9; total time=   0.0s
# [CV] END .............................alpha=10, l1_ratio=0.9; total time=   0.0s
# [CV] END ............................alpha=100, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=100, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=100, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=100, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=100, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=100, l1_ratio=0.4; total time=   0.0s
# [CV] END ............................alpha=100, l1_ratio=0.4; total time=   0.0s
# [CV] END ............................alpha=100, l1_ratio=0.4; total time=   0.0s
# [CV] END ............................alpha=100, l1_ratio=0.4; total time=   0.0s
# [CV] END ............................alpha=100, l1_ratio=0.4; total time=   0.0s
# [CV] END ............................alpha=100, l1_ratio=0.9; total time=   0.0s
# [CV] END ............................alpha=100, l1_ratio=0.9; total time=   0.0s
# [CV] END ............................alpha=100, l1_ratio=0.9; total time=   0.0s
# [CV] END ............................alpha=100, l1_ratio=0.9; total time=   0.0s
# [CV] END ............................alpha=100, l1_ratio=0.9; total time=   0.0s
# {'alpha': 0.1, 'l1_ratio': 0.9}
# ElasticNet(alpha=0.1, l1_ratio=0.9)
# 0.7962409225488818
# 0.8345726087080976

# %%
# elastic net randomized search cv
elastic = ElasticNet()
param_distributions = {"alpha": [0.001 , 0.01, 0.1,1,10,100], "l1_ratio":[0.1,0.4,0.9]}
elastic = RandomizedSearchCV(estimator = elastic, param_distributions=param_distributions, n_iter=2, cv=5, scoring='r2', verbose = 2)

elastic.fit(x_train, y_train)
print(elastic.best_params_)
print(elastic.best_estimator_)
print(elastic.best_score_)
y_pred= elastic.best_estimator_.predict(x_test)
r2_score(y_test, y_pred)
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV] END ............................alpha=100, l1_ratio=0.4; total time=   0.0s
# [CV] END ............................alpha=100, l1_ratio=0.4; total time=   0.0s
# [CV] END ............................alpha=100, l1_ratio=0.4; total time=   0.0s
# [CV] END ............................alpha=100, l1_ratio=0.4; total time=   0.0s
# [CV] END ............................alpha=100, l1_ratio=0.4; total time=   0.0s
# [CV] END ...........................alpha=0.01, l1_ratio=0.4; total time=   0.0s
# [CV] END ...........................alpha=0.01, l1_ratio=0.4; total time=   0.0s
# [CV] END ...........................alpha=0.01, l1_ratio=0.4; total time=   0.0s
# [CV] END ...........................alpha=0.01, l1_ratio=0.4; total time=   0.0s
# [CV] END ...........................alpha=0.01, l1_ratio=0.4; total time=   0.0s
# {'l1_ratio': 0.4, 'alpha': 0.01}
# ElasticNet(alpha=0.01, l1_ratio=0.4)
# 0.7942455989794281
# 0.834963431444709

# %%
#elastic netRandomized Search CV
model = ElasticNet()
param_distributions = {'alpha' : [0.001, 0.01, 0.1, 1, 10, 100],
             'l1_ratio': [0.1,0.4, 0.9]}
model = RandomizedSearchCV(estimator=model, param_distributions = param_distributions,n_iter=2, cv=5, scoring = 'r2', verbose=2)
model.fit(x_train, y_train)
print(model.best_params_)
print(model.best_estimator_)
y_pred = model.best_estimator_.predict(x_test)
print(r2_score(y_test, y_pred))
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV] END ..............................alpha=1, l1_ratio=0.1; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.1; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.1; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.1; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.0s
# {'l1_ratio': 0.1, 'alpha': 0.1}
# ElasticNet(alpha=0.1, l1_ratio=0.1)
# 0.8356976438132142
