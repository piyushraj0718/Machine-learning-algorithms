# %% [markdown]
# # Data interpolation >> is a process of estimating unknown values from the known values
#
#
# # linear interpolation
# # cubic ...
# # polynomial ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.array([1,2,3,4,5])
y =  np.array([1,3,5,7,9])


plt.scatter(x,y)

# %% [markdown]
# # Linear interpolation >> linear in nature

# %%
x_new = np.linspace(1,5,10)  # create new x axis
y_interp = np.interp(x_new , x , y)

# %%
y_interp
# Out:
# array([1.        , 1.88888889, 2.77777778, 3.66666667, 4.55555556,
#        5.44444444, 6.33333333, 7.22222222, 8.11111111, 9.        ])

# %%
plt.scatter(x_new,y_interp)

# %% [markdown]
# # cubic interpolation

# %%
x = np.array([1,2,3,4,5])
y =  np.array([1,8,27,64,125])


plt.scatter(x,y)

# %%
# !pip install scipy

# %%
from scipy.interpolate import interp1d
f = interp1d(x,y,kind='cubic')
f

# %%
x_new = np.linspace(1,5,10)
y_interp = f(x_new)

# %%
y_interp
# Out:
# array([  1.        ,   3.01371742,   6.739369  ,  12.7037037 ,
#         21.43347051,  33.45541838,  49.2962963 ,  69.48285322,
#         94.54183813, 125.        ])

# %%
plt.scatter(x_new,y_interp)

# %% [markdown]
# # polynomial interpolation

# %%
x = np.array([1,2,3,4,5])
y =  np.array([1,4,9,1,25])


plt.scatter(x,y)

# %%
p = np.polyfit(x,y,2)

x_new = np.linspace(x,y,10)
y_interp = np.polyval(p,x_new)

plt.scatter(x_new,y_interp)

# %%
# usecase  >> missing data , generation of new datapoint
